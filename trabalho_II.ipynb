# %% [markdown]
# <a href="https://colab.research.google.com/github/vitu1415/trabalho-II-ML/blob/main/trabalho_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="whitegrid", palette='rocket')

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/ColabNotebooks/dataBase"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(path + '/A519.csv', delimiter=";")

df.head(10)
# Out:
#          data  hora  pressao  radiacao  temp_inst  pto_orvalho_inst  \
# 0  2013-12-03     0    949.3    -3.540       22.3              21.0
# 1  2013-12-03   100    949.7    -3.540       22.1              20.6
# 2  2013-12-03   200    949.4    -3.540       22.1              20.0
# 3  2013-12-03   300    949.1    -3.540       21.9              20.2
# 4  2013-12-03   400    948.6    -3.540       21.4              19.8
# 5  2013-12-03   500    947.8    -3.540       21.2              19.8
# 6  2013-12-03   600    947.3    -3.540       20.8              19.4
# 7  2013-12-03   700    947.7    -3.540       20.4              19.6
# 8  2013-12-03   800    948.3    -3.445       20.4              19.7
# 9  2013-12-03   900    949.2    38.054       20.6              19.8
#
#    umid_inst  vento_vel  Unnamed: 8
# 0       92.0        2.3         NaN
# 1       91.0        2.1         NaN
# 2       88.0        1.3         NaN
# 3       90.0        2.3         NaN
# 4       91.0        1.5         NaN
# 5       92.0        2.0         NaN
# 6       92.0        1.8         NaN
# 7       95.0        1.7         NaN
# 8       95.0        1.8         NaN
# 9       95.0        1.9         NaN

# %%
df_clean = df
df_Clean = df_clean.loc[:, ~df_clean.columns.str.contains("^Unnamed")]

# %%
df_Clean.shape
# Out:
# (83232, 8)

# %%
df_Clean.isnull().sum()
# Out:
# data                   0
# hora                   0
# pressao             5279
# radiacao            5279
# temp_inst           5279
# pto_orvalho_inst    5284
# umid_inst           5285
# vento_vel           5279
# dtype: int64

# %%
df_Clean = df_Clean.dropna()

# %%
df_Clean.shape
# Out:
# (77945, 8)

# %% [markdown]
# limpando dados null, que não agregariam na analise

# %% [markdown]
# # Transformação das Datas

# %%
df_Clean["data"] = pd.to_datetime(df_Clean["data"])

df_Clean["ano"] = df_Clean["data"].dt.year
df_Clean["mes"] = df_Clean["data"].dt.month
df_Clean["dia"] = df_Clean["data"].dt.day

# %%
df_Clean["hora"] = df_Clean["hora"] // 100

# %% [markdown]
# tratamento das horas, estava em HH:MM, assim dividindo por 100, para ter exatamente a hora em especifico

# %%
df_Clean.head(10)
# Out:
#         data  hora  pressao  radiacao  temp_inst  pto_orvalho_inst  umid_inst  \
# 0 2013-12-03     0    949.3    -3.540       22.3              21.0       92.0
# 1 2013-12-03     1    949.7    -3.540       22.1              20.6       91.0
# 2 2013-12-03     2    949.4    -3.540       22.1              20.0       88.0
# 3 2013-12-03     3    949.1    -3.540       21.9              20.2       90.0
# 4 2013-12-03     4    948.6    -3.540       21.4              19.8       91.0
# 5 2013-12-03     5    947.8    -3.540       21.2              19.8       92.0
# 6 2013-12-03     6    947.3    -3.540       20.8              19.4       92.0
# 7 2013-12-03     7    947.7    -3.540       20.4              19.6       95.0
# 8 2013-12-03     8    948.3    -3.445       20.4              19.7       95.0
# 9 2013-12-03     9    949.2    38.054       20.6              19.8       95.0
#
#    vento_vel   ano  mes  dia
# 0        2.3  2013   12    3
# 1        2.1  2013   12    3
# 2        1.3  2013   12    3
# 3        2.3  2013   12    3
# 4        1.5  2013   12    3
# 5        2.0  2013   12    3
# 6        1.8  2013   12    3
# 7        1.7  2013   12    3
# 8        1.8  2013   12    3
# 9        1.9  2013   12    3
